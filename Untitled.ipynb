# %% [markdown]
# # Primo script di prova!

# %%
import numpy as np
import pandas as pd

# %%
dataset = pd.read_csv('dc_data.csv')

# %%
dataset.describe()
# Out:
#        Sync errors  Last authorization status update time  Daily budget  \
# count          0.0                                    0.0     63.000000
# mean           NaN                                    NaN    159.102857
# std            NaN                                    NaN    193.247527
# min            NaN                                    NaN      5.000000
# 25%            NaN                                    NaN     38.000000
# 50%            NaN                                    NaN    110.000000
# 75%            NaN                                    NaN    200.000000
# max            NaN                                    NaN   1400.000000
#
#              Clicks           Impr          Cost        CTR    Avg CPC  \
# count     76.000000      76.000000     76.000000  76.000000  75.000000
# mean    1810.513158   55657.421053    858.417632   0.086787   0.430267
# std     3285.985776  109259.270444   2060.584080   0.116812   0.345050
# ...

# %%
dataset
# Out:
#            Row Type  Status  Sync errors                     Advertiser  \
# 0        advertiser  Active          NaN                     Supermoney
# 1        advertiser  Active          NaN             Supermoney_Energia
# 2        advertiser  Active          NaN            Supermoney_Prestiti
# 3        advertiser  Active          NaN           Supermoney_Telefonia
# 4        advertiser  Active          NaN  Supermoney_Assicurazioni Auto
# 5    engine account  Active          NaN                     Supermoney
# 6    engine account  Active          NaN            Supermoney_Prestiti
# 7    engine account  Active          NaN             Supermoney_Energia
# 8    engine account  Active          NaN                     Supermoney
# 9    engine account  Active          NaN             Supermoney_Energia
# 10   engine account  Active          NaN           Supermoney_Telefonia
# 11   engine account  Active          NaN  Supermoney_Assicurazioni Auto
# ...

# %%
dataset_clean = dataset[pd.notnull(dataset['BU'])]

# %%
dataset_clean.drop(dataset_clean.columns[18], axis=1, inplace = True)
# Out:
# C:\Users\enzos\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
dataset_clean
# Out:
#     Row Type  Status  Sync errors                     Advertiser  \
# 13  campaign  Active          NaN  Supermoney_Assicurazioni Auto
# 14  campaign  Active          NaN            Supermoney_Prestiti
# 15  campaign  Active          NaN             Supermoney_Energia
# 16  campaign  Active          NaN                     Supermoney
# 17  campaign  Active          NaN             Supermoney_Energia
# 18  campaign  Active          NaN             Supermoney_Energia
# 19  campaign  Active          NaN            Supermoney_Prestiti
# 20  campaign  Active          NaN  Supermoney_Assicurazioni Auto
# 21  campaign  Active          NaN                     Supermoney
# 22  campaign  Active          NaN           Supermoney_Telefonia
# 23  campaign  Active          NaN            Supermoney_Prestiti
# 24  campaign  Active          NaN           Supermoney_Telefonia
# 25  campaign  Active          NaN  Supermoney_Assicurazioni Auto
# ...

# %%
energia = dataset_clean.loc[dataset_clean['BU'] == 'ENERGIA']

# %%
energia.describe()
# Out:
#        Sync errors  Last authorization status update time  Daily budget  \
# count          0.0                                    0.0     15.000000
# mean           NaN                                    NaN    169.165333
# std            NaN                                    NaN    346.631367
# min            NaN                                    NaN      7.000000
# 25%            NaN                                    NaN     31.650000
# 50%            NaN                                    NaN     84.210000
# 75%            NaN                                    NaN    113.500000
# max            NaN                                    NaN   1400.000000
#
#             Clicks           Impr         Cost        CTR    Avg CPC  \
# count    15.000000      15.000000    15.000000  15.000000  15.000000
# mean   1053.466667   26730.333333   738.456000   0.094453   0.567333
# std    1380.504145   38660.809813  1667.227064   0.141847   0.364857
# ...

# %%
import matplotlib as mp
